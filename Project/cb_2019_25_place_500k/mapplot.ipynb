# %%
import geopandas as gpd
import matplotlib.pyplot as plt
gdf = gpd.read_file('./cb_2019_25_place_500k.shp')
gdf.plot()
# Out:
# <AxesSubplot:>

# %%
print(gdf)
# Out:
#     STATEFP PLACEFP   PLACENS          AFFGEOID    GEOID              NAME  \
# 0        25   19370  00618199  1600000US2519370  2519370  Easthampton Town
# 1        25   40115  00619406  1600000US2540115  2540115           Melrose
# 2        25   55535  02378207  1600000US2555535  2555535      Provincetown
# 3        25   56095  02378209  1600000US2556095  2556095    Raynham Center
# 4        25   28425  02727442  1600000US2528425  2528425       Hanscom AFB
# ..      ...     ...       ...               ...      ...               ...
# 240      25   11000  00619396  1600000US2511000  2511000         Cambridge
# 241      25   50005  02378192  1600000US2550005  2550005     Norton Center
# 242      25   41725  02378170  1600000US2541725  2541725            Milton
# 243      25   73440  00618242  1600000US2573440  2573440    Watertown Town
# 244      25   67700  02378235  1600000US2567700  2567700          Stoneham
#
# ...
